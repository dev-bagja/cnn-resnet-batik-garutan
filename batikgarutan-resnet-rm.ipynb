# %%
# import library

import matplotlib.pyplot as plt
import numpy as np
import os
import PIL
import tensorflow as tf
import cv2
import seaborn as sns

from sklearn.metrics import classification_report,confusion_matrix

import keras
from keras.models import Sequential
from keras.layers import Dense, Conv2D , MaxPool2D , Flatten , Dropout 
from keras.preprocessing.image import ImageDataGenerator

from tensorflow.keras.optimizers import Adam

# %%
labels = ['RM', 'batik-lain']
img_size = 224
def get_data(data_dir):
    data = [] 
    for label in labels: 
        path = os.path.join(data_dir, label)
        class_num = labels.index(label)
        for img in os.listdir(path):
            try:
                img_arr = cv2.imread(os.path.join(path, img))[...,::-1] #convert BGR to RGB format
                resized_arr = cv2.resize(img_arr, (img_size, img_size)) # Reshaping images to preferred size
                data.append([resized_arr, class_num])
            except Exception as e:
                print(e)
    return np.array(data)

# %%
# Now we can easily fetch our train and validation data.

from google.colab import drive

drive.mount('/content/gdrive', force_remount=True)
train = get_data('/content/gdrive/MyDrive/Colab Notebooks/skripsi/datasetv2/train')
val = get_data('/content/gdrive/MyDrive/Colab Notebooks/skripsi/datasetv2/test')
# Out:
# Mounted at /content/gdrive
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:15: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   from ipykernel import kernelapp as app

# %%
print(val.shape)
# Out:
# (150, 2)

# %%
l = []
for i in train:
    if(i[1] == 0):
        l.append("RM")
    else:
        l.append("batik-lain")
sns.set_style('darkgrid')
sns.countplot(l)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
plt.figure(figsize = (5,5))
plt.imshow(train[1][0])
plt.title(labels[train[0][1]])
# Out:
# Text(0.5, 1.0, 'RM')

# %%
plt.figure(figsize = (5,5))
plt.imshow(train[-1][0])
plt.title(labels[train[-1][1]])
# Out:
# Text(0.5, 1.0, 'batik-lain')

# %%
x_train = []
y_train = []
x_val = []
y_val = []

for feature, label in train:
  x_train.append(feature)
  y_train.append(label)

for feature, label in val:
  x_val.append(feature)
  y_val.append(label)

# Normalize the data
x_train = np.array(x_train) / 255
x_val = np.array(x_val) / 255

x_train.reshape(-1, img_size, img_size, 1)
y_train = np.array(y_train)

x_val.reshape(-1, img_size, img_size, 1)
y_val = np.array(y_val)

# %%
datagen = ImageDataGenerator(
    zoom_range = 0.3,
    horizontal_flip = True,
    vertical_flip=True,
    rotation_range=90)


datagen.fit(x_train)

# %%
pretrained_model = tf.keras.applications.ResNet50(
    include_top=False,
    input_shape=(224,224,3),
    pooling='max',
    # classes=2,
    weights='imagenet'
    )

pretrained_model.trainable=False
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet50_weights_tf_dim_ordering_tf_kernels_notop.h5
# 94773248/94765736 [==============================] - 1s 0us/step
# 94781440/94765736 [==============================] - 1s 0us/step

# %%
resnet_model = Sequential()

resnet_model.add(pretrained_model)
resnet_model.add(Flatten())
resnet_model.add(Dense(512, activation='relu'))
resnet_model.add(Dense(1, activation='sigmoid'))

resnet_model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  resnet50 (Functional)       (None, 2048)              23587712
#
#  flatten (Flatten)           (None, 2048)              0
#
#  dense (Dense)               (None, 512)               1049088
#
#  dense_1 (Dense)             (None, 1)                 513
#
# =================================================================
# Total params: 24,637,313
# Trainable params: 1,049,601
# Non-trainable params: 23,587,712
# _________________________________________________________________

# %%
base_learning_rate = 0.00001

# resnet_model.compile(optimizer=tf.keras.optimizers.Adam(lr=base_learning_rate),
#               loss=tf.keras.losses.BinaryCrossentropy(from_logits=True),
#               metrics=['accuracy'])
resnet_model.compile(
    optimizer=Adam(learning_rate=0.00001),
    loss='binary_crossentropy',
    metrics=['accuracy']
    )

history = resnet_model.fit(x_train,y_train,epochs = 100, validation_data = (x_val, y_val))
# Out:
# Epoch 1/100
# 7/7 [==============================] - 54s 8s/step - loss: 2.2136 - accuracy: 0.5000 - val_loss: 3.1716 - val_accuracy: 0.1667
# Epoch 2/100
# 7/7 [==============================] - 47s 7s/step - loss: 1.6129 - accuracy: 0.5000 - val_loss: 2.1554 - val_accuracy: 0.1667
# Epoch 3/100
# 7/7 [==============================] - 48s 7s/step - loss: 1.1001 - accuracy: 0.5000 - val_loss: 1.3079 - val_accuracy: 0.1800
# Epoch 4/100
# 7/7 [==============================] - 47s 7s/step - loss: 0.7727 - accuracy: 0.4950 - val_loss: 0.8075 - val_accuracy: 0.3867
# Epoch 5/100
# 7/7 [==============================] - 48s 7s/step - loss: 0.7032 - accuracy: 0.5350 - val_loss: 0.6093 - val_accuracy: 0.6933
# Epoch 6/100
# 7/7 [==============================] - 47s 7s/step - loss: 0.7146 - accuracy: 0.5300 - val_loss: 0.5846 - val_accuracy: 0.7467
# Epoch 7/100
# 7/7 [==============================] - 48s 7s/step - loss: 0.7022 - accuracy: 0.5500 - val_loss: 0.6317 - val_accuracy: 0.6667
# Epoch 8/100
# 7/7 [==============================] - 49s 8s/step - loss: 0.6756 - accuracy: 0.5600 - val_loss: 0.6755 - val_accuracy: 0.6067
# Epoch 9/100
# 7/7 [==============================] - 47s 7s/step - loss: 0.6656 - accuracy: 0.5750 - val_loss: 0.7174 - val_accuracy: 0.5200
# Epoch 10/100
# 7/7 [==============================] - 48s 7s/step - loss: 0.6574 - accuracy: 0.5500 - val_loss: 0.7227 - val_accuracy: 0.5267
# Epoch 11/100
# 7/7 [==============================] - 47s 7s/step - loss: 0.6507 - accuracy: 0.5750 - val_loss: 0.7021 - val_accuracy: 0.5467
# Epoch 12/100
# 7/7 [==============================] - 47s 7s/step - loss: 0.6431 - accuracy: 0.5650 - val_loss: 0.6605 - val_accuracy: 0.6133
# Epoch 13/100
# 7/7 [==============================] - 47s 7s/step - loss: 0.6347 - accuracy: 0.5700 - val_loss: 0.6446 - val_accuracy: 0.6333
# Epoch 14/100
# 7/7 [==============================] - 47s 7s/step - loss: 0.6284 - accuracy: 0.5850 - val_loss: 0.6346 - val_accuracy: 0.6600
# Epoch 15/100
# 7/7 [==============================] - 49s 7s/step - loss: 0.6209 - accuracy: 0.5900 - val_loss: 0.6518 - val_accuracy: 0.6333
# Epoch 16/100
# 7/7 [==============================] - 47s 7s/step - loss: 0.6161 - accuracy: 0.6050 - val_loss: 0.6639 - val_accuracy: 0.6000
# Epoch 17/100
# 7/7 [==============================] - 47s 7s/step - loss: 0.6094 - accuracy: 0.6300 - val_loss: 0.6349 - val_accuracy: 0.6733
# Epoch 18/100
# 7/7 [==============================] - 47s 7s/step - loss: 0.6047 - accuracy: 0.6400 - val_loss: 0.5996 - val_accuracy: 0.7333
# Epoch 19/100
# 7/7 [==============================] - 47s 7s/step - loss: 0.5999 - accuracy: 0.6600 - val_loss: 0.6046 - val_accuracy: 0.7133
# Epoch 20/100
# 7/7 [==============================] - 47s 7s/step - loss: 0.5938 - accuracy: 0.6600 - val_loss: 0.6395 - val_accuracy: 0.6333
# Epoch 21/100
# 7/7 [==============================] - 48s 7s/step - loss: 0.5904 - accuracy: 0.6600 - val_loss: 0.6716 - val_accuracy: 0.6067
# Epoch 22/100
# 7/7 [==============================] - 48s 7s/step - loss: 0.5856 - accuracy: 0.6600 - val_loss: 0.6417 - val_accuracy: 0.6467
# Epoch 23/100
# 7/7 [==============================] - 47s 7s/step - loss: 0.5784 - accuracy: 0.6850 - val_loss: 0.6079 - val_accuracy: 0.6800
# Epoch 24/100
# 7/7 [==============================] - 47s 7s/step - loss: 0.5757 - accuracy: 0.6650 - val_loss: 0.6116 - val_accuracy: 0.6800
# Epoch 25/100
# 7/7 [==============================] - 48s 7s/step - loss: 0.5731 - accuracy: 0.6700 - val_loss: 0.5911 - val_accuracy: 0.7133
# Epoch 26/100
# 7/7 [==============================] - 48s 7s/step - loss: 0.5666 - accuracy: 0.6750 - val_loss: 0.6138 - val_accuracy: 0.6867
# Epoch 27/100
# 7/7 [==============================] - 47s 7s/step - loss: 0.5633 - accuracy: 0.7050 - val_loss: 0.6073 - val_accuracy: 0.6867
# Epoch 28/100
# 7/7 [==============================] - 49s 7s/step - loss: 0.5612 - accuracy: 0.6850 - val_loss: 0.6277 - val_accuracy: 0.6533
# Epoch 29/100
# 7/7 [==============================] - 47s 7s/step - loss: 0.5578 - accuracy: 0.7000 - val_loss: 0.6276 - val_accuracy: 0.6467
# Epoch 30/100
# 7/7 [==============================] - 47s 7s/step - loss: 0.5524 - accuracy: 0.7050 - val_loss: 0.5911 - val_accuracy: 0.7067
# Epoch 31/100
# 7/7 [==============================] - 47s 7s/step - loss: 0.5487 - accuracy: 0.6900 - val_loss: 0.5918 - val_accuracy: 0.7067
# Epoch 32/100
# 7/7 [==============================] - 47s 7s/step - loss: 0.5455 - accuracy: 0.7000 - val_loss: 0.5948 - val_accuracy: 0.7000
# Epoch 33/100
# 7/7 [==============================] - 47s 7s/step - loss: 0.5425 - accuracy: 0.7150 - val_loss: 0.6241 - val_accuracy: 0.6467
# Epoch 34/100
# 7/7 [==============================] - 47s 7s/step - loss: 0.5392 - accuracy: 0.7200 - val_loss: 0.6323 - val_accuracy: 0.6133
# Epoch 35/100
# 7/7 [==============================] - 49s 7s/step - loss: 0.5367 - accuracy: 0.7200 - val_loss: 0.6059 - val_accuracy: 0.6800
# Epoch 36/100
# 7/7 [==============================] - 47s 7s/step - loss: 0.5361 - accuracy: 0.7250 - val_loss: 0.5768 - val_accuracy: 0.7267
# Epoch 37/100
# 7/7 [==============================] - 47s 7s/step - loss: 0.5302 - accuracy: 0.7300 - val_loss: 0.6178 - val_accuracy: 0.6467
# Epoch 38/100
# 7/7 [==============================] - 47s 7s/step - loss: 0.5278 - accuracy: 0.7350 - val_loss: 0.6268 - val_accuracy: 0.6267
# Epoch 39/100
# 7/7 [==============================] - 47s 7s/step - loss: 0.5243 - accuracy: 0.7350 - val_loss: 0.6096 - val_accuracy: 0.6600
# Epoch 40/100
# 7/7 [==============================] - 47s 7s/step - loss: 0.5224 - accuracy: 0.7400 - val_loss: 0.6020 - val_accuracy: 0.6667
# Epoch 41/100
# 7/7 [==============================] - 47s 7s/step - loss: 0.5181 - accuracy: 0.7500 - val_loss: 0.6073 - val_accuracy: 0.6467
# Epoch 42/100
# 7/7 [==============================] - 49s 7s/step - loss: 0.5167 - accuracy: 0.7450 - val_loss: 0.6010 - val_accuracy: 0.6467
# Epoch 43/100
# 7/7 [==============================] - 48s 7s/step - loss: 0.5144 - accuracy: 0.7450 - val_loss: 0.6051 - val_accuracy: 0.6467
# Epoch 44/100
# 7/7 [==============================] - 47s 7s/step - loss: 0.5102 - accuracy: 0.7600 - val_loss: 0.5721 - val_accuracy: 0.7067
# Epoch 45/100
# 7/7 [==============================] - 47s 7s/step - loss: 0.5077 - accuracy: 0.7500 - val_loss: 0.5593 - val_accuracy: 0.7267
# Epoch 46/100
# 7/7 [==============================] - 47s 7s/step - loss: 0.5076 - accuracy: 0.7500 - val_loss: 0.5600 - val_accuracy: 0.7200
# Epoch 47/100
# 7/7 [==============================] - 47s 7s/step - loss: 0.5090 - accuracy: 0.7550 - val_loss: 0.5428 - val_accuracy: 0.7600
# Epoch 48/100
# 7/7 [==============================] - 49s 7s/step - loss: 0.5051 - accuracy: 0.7600 - val_loss: 0.5705 - val_accuracy: 0.7000
# Epoch 49/100
# 7/7 [==============================] - 47s 7s/step - loss: 0.5008 - accuracy: 0.7500 - val_loss: 0.6194 - val_accuracy: 0.6200
# Epoch 50/100
# 7/7 [==============================] - 47s 7s/step - loss: 0.4989 - accuracy: 0.7550 - val_loss: 0.6285 - val_accuracy: 0.6267
# Epoch 51/100
# 7/7 [==============================] - 47s 7s/step - loss: 0.4962 - accuracy: 0.7550 - val_loss: 0.6025 - val_accuracy: 0.6333
# Epoch 52/100
# 7/7 [==============================] - 47s 7s/step - loss: 0.4926 - accuracy: 0.7650 - val_loss: 0.5695 - val_accuracy: 0.6867
# Epoch 53/100
# 7/7 [==============================] - 47s 7s/step - loss: 0.4925 - accuracy: 0.7550 - val_loss: 0.5514 - val_accuracy: 0.7067
# Epoch 54/100
# 7/7 [==============================] - 47s 7s/step - loss: 0.4908 - accuracy: 0.7600 - val_loss: 0.5961 - val_accuracy: 0.6400
# Epoch 55/100
# 7/7 [==============================] - 49s 7s/step - loss: 0.4879 - accuracy: 0.7550 - val_loss: 0.5821 - val_accuracy: 0.6533
# Epoch 56/100
# 7/7 [==============================] - 47s 7s/step - loss: 0.4852 - accuracy: 0.7700 - val_loss: 0.5536 - val_accuracy: 0.7067
# Epoch 57/100
# 7/7 [==============================] - 47s 7s/step - loss: 0.4840 - accuracy: 0.7750 - val_loss: 0.5735 - val_accuracy: 0.6667
# Epoch 58/100
# 7/7 [==============================] - 47s 7s/step - loss: 0.4813 - accuracy: 0.7750 - val_loss: 0.5806 - val_accuracy: 0.6467
# Epoch 59/100
# 7/7 [==============================] - 47s 7s/step - loss: 0.4795 - accuracy: 0.7800 - val_loss: 0.5803 - val_accuracy: 0.6533
# Epoch 60/100
# 7/7 [==============================] - 47s 7s/step - loss: 0.4781 - accuracy: 0.7700 - val_loss: 0.6009 - val_accuracy: 0.6333
# Epoch 61/100
# 7/7 [==============================] - 47s 7s/step - loss: 0.4765 - accuracy: 0.7650 - val_loss: 0.5854 - val_accuracy: 0.6400
# Epoch 62/100
# 7/7 [==============================] - 49s 7s/step - loss: 0.4748 - accuracy: 0.7750 - val_loss: 0.5728 - val_accuracy: 0.6600
# Epoch 63/100
# 7/7 [==============================] - 47s 7s/step - loss: 0.4731 - accuracy: 0.7700 - val_loss: 0.5985 - val_accuracy: 0.6267
# Epoch 64/100
# 7/7 [==============================] - 47s 7s/step - loss: 0.4730 - accuracy: 0.7700 - val_loss: 0.5719 - val_accuracy: 0.6533
# Epoch 65/100
# 7/7 [==============================] - 47s 7s/step - loss: 0.4693 - accuracy: 0.7800 - val_loss: 0.5724 - val_accuracy: 0.6533
# Epoch 66/100
# 7/7 [==============================] - 47s 7s/step - loss: 0.4688 - accuracy: 0.7950 - val_loss: 0.5497 - val_accuracy: 0.6867
# Epoch 67/100
# 7/7 [==============================] - 47s 7s/step - loss: 0.4659 - accuracy: 0.7850 - val_loss: 0.5738 - val_accuracy: 0.6400
# Epoch 68/100
# 7/7 [==============================] - 49s 7s/step - loss: 0.4645 - accuracy: 0.7850 - val_loss: 0.5818 - val_accuracy: 0.6400
# Epoch 69/100
# 7/7 [==============================] - 47s 7s/step - loss: 0.4647 - accuracy: 0.7800 - val_loss: 0.5675 - val_accuracy: 0.6667
# Epoch 70/100
# 7/7 [==============================] - 47s 7s/step - loss: 0.4611 - accuracy: 0.7800 - val_loss: 0.5810 - val_accuracy: 0.6267
# Epoch 71/100
# 7/7 [==============================] - 47s 7s/step - loss: 0.4602 - accuracy: 0.7750 - val_loss: 0.5677 - val_accuracy: 0.6600
# Epoch 72/100
# 7/7 [==============================] - 47s 7s/step - loss: 0.4589 - accuracy: 0.7800 - val_loss: 0.5784 - val_accuracy: 0.6400
# Epoch 73/100
# 7/7 [==============================] - 47s 7s/step - loss: 0.4568 - accuracy: 0.7800 - val_loss: 0.5622 - val_accuracy: 0.6533
# Epoch 74/100
# 7/7 [==============================] - 47s 7s/step - loss: 0.4553 - accuracy: 0.7900 - val_loss: 0.5718 - val_accuracy: 0.6467
# Epoch 75/100
# 7/7 [==============================] - 48s 7s/step - loss: 0.4551 - accuracy: 0.7800 - val_loss: 0.5962 - val_accuracy: 0.6267
# Epoch 76/100
# 7/7 [==============================] - 47s 7s/step - loss: 0.4540 - accuracy: 0.7950 - val_loss: 0.5896 - val_accuracy: 0.6267
# Epoch 77/100
# 7/7 [==============================] - 47s 7s/step - loss: 0.4512 - accuracy: 0.7800 - val_loss: 0.5653 - val_accuracy: 0.6600
# Epoch 78/100
# 7/7 [==============================] - 47s 7s/step - loss: 0.4493 - accuracy: 0.8000 - val_loss: 0.5221 - val_accuracy: 0.7333
# Epoch 79/100
# 7/7 [==============================] - 47s 7s/step - loss: 0.4518 - accuracy: 0.8150 - val_loss: 0.5558 - val_accuracy: 0.6800
# Epoch 80/100
# 7/7 [==============================] - 47s 7s/step - loss: 0.4496 - accuracy: 0.7850 - val_loss: 0.6210 - val_accuracy: 0.6067
# Epoch 81/100
# 7/7 [==============================] - 47s 7s/step - loss: 0.4476 - accuracy: 0.7900 - val_loss: 0.5870 - val_accuracy: 0.6333
# Epoch 82/100
# 7/7 [==============================] - 48s 7s/step - loss: 0.4455 - accuracy: 0.8000 - val_loss: 0.5585 - val_accuracy: 0.6600
# Epoch 83/100
# 7/7 [==============================] - 47s 7s/step - loss: 0.4438 - accuracy: 0.8000 - val_loss: 0.5700 - val_accuracy: 0.6400
# Epoch 84/100
# 7/7 [==============================] - 47s 7s/step - loss: 0.4411 - accuracy: 0.7950 - val_loss: 0.5644 - val_accuracy: 0.6400
# Epoch 85/100
# 7/7 [==============================] - 47s 7s/step - loss: 0.4409 - accuracy: 0.7900 - val_loss: 0.5629 - val_accuracy: 0.6400
# Epoch 86/100
# 7/7 [==============================] - 47s 7s/step - loss: 0.4382 - accuracy: 0.8100 - val_loss: 0.5362 - val_accuracy: 0.6933
# Epoch 87/100
# 7/7 [==============================] - 47s 7s/step - loss: 0.4389 - accuracy: 0.8250 - val_loss: 0.5338 - val_accuracy: 0.6933
# Epoch 88/100
# 7/7 [==============================] - 48s 7s/step - loss: 0.4412 - accuracy: 0.8000 - val_loss: 0.5864 - val_accuracy: 0.6400
# Epoch 89/100
# 7/7 [==============================] - 47s 7s/step - loss: 0.4347 - accuracy: 0.8050 - val_loss: 0.5595 - val_accuracy: 0.6400
# Epoch 90/100
# 7/7 [==============================] - 47s 7s/step - loss: 0.4333 - accuracy: 0.8000 - val_loss: 0.5583 - val_accuracy: 0.6400
# Epoch 91/100
# 7/7 [==============================] - 47s 7s/step - loss: 0.4321 - accuracy: 0.8000 - val_loss: 0.5696 - val_accuracy: 0.6400
# Epoch 92/100
# 7/7 [==============================] - 47s 7s/step - loss: 0.4304 - accuracy: 0.8050 - val_loss: 0.5599 - val_accuracy: 0.6467
# Epoch 93/100
# 7/7 [==============================] - 47s 7s/step - loss: 0.4307 - accuracy: 0.8150 - val_loss: 0.5392 - val_accuracy: 0.6867
# Epoch 94/100
# 7/7 [==============================] - 47s 7s/step - loss: 0.4322 - accuracy: 0.8250 - val_loss: 0.5422 - val_accuracy: 0.6867
# Epoch 95/100
# 7/7 [==============================] - 48s 7s/step - loss: 0.4269 - accuracy: 0.8050 - val_loss: 0.5773 - val_accuracy: 0.6400
# Epoch 96/100
# 7/7 [==============================] - 47s 7s/step - loss: 0.4267 - accuracy: 0.8100 - val_loss: 0.5972 - val_accuracy: 0.6267
# Epoch 97/100
# 7/7 [==============================] - 47s 7s/step - loss: 0.4277 - accuracy: 0.8000 - val_loss: 0.5651 - val_accuracy: 0.6400
# Epoch 98/100
# 7/7 [==============================] - 47s 7s/step - loss: 0.4244 - accuracy: 0.8200 - val_loss: 0.5875 - val_accuracy: 0.6333
# Epoch 99/100
# 7/7 [==============================] - 47s 7s/step - loss: 0.4227 - accuracy: 0.8150 - val_loss: 0.5544 - val_accuracy: 0.6533
# Epoch 100/100
# 7/7 [==============================] - 47s 7s/step - loss: 0.4216 - accuracy: 0.8150 - val_loss: 0.5581 - val_accuracy: 0.6533

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']
epochs_range = range(100)

plt.figure(figsize=(15, 15))
plt.subplot(2, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(2, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %%
p_pred = resnet_model.predict(x_val)
p_pred = p_pred.reshape(1,-1)[0]
# p_pred = p_pred.flatten()
# print(p_pred.round(2))

# extract the predicted class labels
y_pred = np.where(p_pred > 0.5, 1, 0)

print(confusion_matrix(y_val, y_pred))
print(classification_report(y_val, y_pred, target_names = ['Batik Garutan','Batik Lain']))
# Out:
# [[79 46]
#  [ 6 19]]
#                precision    recall  f1-score   support
#
# Batik Garutan       0.93      0.63      0.75       125
#    Batik Lain       0.29      0.76      0.42        25
#
#      accuracy                           0.65       150
#     macro avg       0.61      0.70      0.59       150
#  weighted avg       0.82      0.65      0.70       150
